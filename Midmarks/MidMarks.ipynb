# %% [markdown]
# # M.charan reddy

# %% [markdown]
# # 2211cs010327

# %% [markdown]
# # Group 04

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action="ignore", category=pd.errors.SettingWithCopyWarning)
df = pd.read_excel("MIDMARKS-MINOR1-EXAM.xlsx")
df
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 475   476     NaN  18    2  12    3  17   15
# 476   477     NaN  20    6  16   11  20   14
# 477   478     NaN  20  NaN  18   13  20   18
# 478   479     NaN  20   20   5   19  18   14
# 479   480     NaN  20   16  18   19  20   19
#
# [480 rows x 8 columns]

# %%
df = df.fillna(0)

# %%
columns_to_convert = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce').astype("Int64")

# %%
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS
# 0       1   ALPHA  12     0  17     9  19    15
# 1       2   ALPHA  19    12  16    16  18     3
# 2       3   ALPHA  18    14  18    18  18    16
# 3       4   ALPHA  15     9  19    17  19    15
# 4       5   ALPHA  18    17  19    19  20    18
# ..    ...     ...  ..   ...  ..   ...  ..   ...
# 475   476       0  18     2  12     3  17    15
# 476   477       0  20     6  16    11  20    14
# 477   478       0  20     0  18    13  20    18
# 478   479       0  20    20   5    19  18    14
# 479   480       0  20    16  18    19  20    19
#
# [480 rows x 8 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS
# 0       1   ALPHA  12     0  17     9  19    15
# 1       2   ALPHA  19    12  16    16  18     3
# 2       3   ALPHA  18    14  18    18  18    16
# 3       4   ALPHA  15     9  19    17  19    15
# 4       5   ALPHA  18    17  19    19  20    18
# ..    ...     ...  ..   ...  ..   ...  ..   ...
# 475   476       0  18     2  12     3  17    15
# 476   477       0  20     6  16    11  20    14
# 477   478       0  20     0  18    13  20    18
# 478   479       0  20    20   5    19  18    14
# 479   480       0  20    16  18    19  20    19
#
# [480 rows x 8 columns]>

# %%
df['FL'] = df['FL'].fillna(0) 
df=df.dropna()

# %%
df.loc[:, 'S.NO'] = range(1, len(df) + 1)
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS
# 0       1   ALPHA  12     0  17     9  19    15
# 1       2   ALPHA  19    12  16    16  18     3
# 2       3   ALPHA  18    14  18    18  18    16
# 3       4   ALPHA  15     9  19    17  19    15
# 4       5   ALPHA  18    17  19    19  20    18
# ..    ...     ...  ..   ...  ..   ...  ..   ...
# 475   451       0  18     2  12     3  17    15
# 476   452       0  20     6  16    11  20    14
# 477   453       0  20     0  18    13  20    18
# 478   454       0  20    20   5    19  18    14
# 479   455       0  20    16  18    19  20    19
#
# [455 rows x 8 columns]

# %%
df.loc[:, 'SECTION'] = df['SECTION'].fillna('SIGMA')
df.loc[:, 'SECTION'] = df['SECTION'].replace('', 'SIGMA')
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS
# 0       1   ALPHA  12     0  17     9  19    15
# 1       2   ALPHA  19    12  16    16  18     3
# 2       3   ALPHA  18    14  18    18  18    16
# 3       4   ALPHA  15     9  19    17  19    15
# 4       5   ALPHA  18    17  19    19  20    18
# ..    ...     ...  ..   ...  ..   ...  ..   ...
# 475   451       0  18     2  12     3  17    15
# 476   452       0  20     6  16    11  20    14
# 477   453       0  20     0  18    13  20    18
# 478   454       0  20    20   5    19  18    14
# 479   455       0  20    16  18    19  20    19
#
# [455 rows x 8 columns]

# %%
from scipy.stats import ttest_ind

group1 = df[df['SECTION']=='ALPHA']
group2 = df[df['SECTION']=='DELTA']
ttest_ind(group1['DV'],group2['DV'])
# Out:
# TtestResult(statistic=0.36930333301116813, pvalue=0.7125867066587055, df=114.0)

# %%
df["Total"]=df["DV"]+df["M-II"]+df["PP"]+df["BEEE"]+df["FL"]+df["FIMS"]
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total
# 0       1   ALPHA  12     0  17     9  19    15     72
# 1       2   ALPHA  19    12  16    16  18     3     84
# 2       3   ALPHA  18    14  18    18  18    16    102
# 3       4   ALPHA  15     9  19    17  19    15     94
# 4       5   ALPHA  18    17  19    19  20    18    111
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...
# 475   451       0  18     2  12     3  17    15     67
# 476   452       0  20     6  16    11  20    14     87
# 477   453       0  20     0  18    13  20    18     89
# 478   454       0  20    20   5    19  18    14     96
# 479   455       0  20    16  18    19  20    19    112
#
# [455 rows x 9 columns]

# %%
df.loc[:, 'TOTAL'] = df["DV"] + df["M-II"] + df["PP"] + df["BEEE"] + df["FL"] + df["FIMS"]
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL
# 0       1   ALPHA  12     0  17     9  19    15     72     72
# 1       2   ALPHA  19    12  16    16  18     3     84     84
# 2       3   ALPHA  18    14  18    18  18    16    102    102
# 3       4   ALPHA  15     9  19    17  19    15     94     94
# 4       5   ALPHA  18    17  19    19  20    18    111    111
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...
# 475   451       0  18     2  12     3  17    15     67     67
# 476   452       0  20     6  16    11  20    14     87     87
# 477   453       0  20     0  18    13  20    18     89     89
# 478   454       0  20    20   5    19  18    14     96     96
# 479   455       0  20    16  18    19  20    19    112    112
#
# [455 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

def plot_histograms_boxplots(data, column, group_col, group1, group2):
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    group1_data = data[data[group_col] == group1][column]
    group2_data = data[data[group_col] == group2][column]

    sns.histplot(group1_data, kde=True, color="blue", label=group1, ax=axes[0], alpha=0.5)
    sns.histplot(group2_data, kde=True, color="red", label=group2, ax=axes[0], alpha=0.5)
    axes[0].set_title(f'Histogram of {column} ({group1} vs {group2})')
    axes[0].legend()

    sns.boxplot(x=data[group_col], y=data[column], ax=axes[1])
    axes[1].set_title(f'Boxplot of {column} by {group_col}')

    plt.tight_layout()
    plt.show()

plot_histograms_boxplots(df, column="DV", group_col="SECTION", group1="ALPHA",group2="BETA")

# %%
df[df['SECTION']=="ALPHA"].DV.mean()
# Out:
# 14.101694915254237

# %%
import scipy.stats as stats

# %%
t_statistic, p_value = stats.ttest_1samp(df[df["SECTION"] =="ALPHA"] ["DV"] , df.DV.mean())
print(t_statistic,p_value)
# Out:
# -1.1175863975345808 0.26835166742242034

# %%
from scipy import stats

t_statistic, p_value = stats.ttest_1samp(df[df["SECTION"] == "ALPHA"]["DV"], df["DV"].mean())
print(t_statistic,p_value)
# Out:
# -1.1175863975345808 0.26835166742242034

# %%
from scipy.stats import ttest_1samp
import pandas as pd

# Ensure 'DV' is numeric
df['DV'] = pd.to_numeric(df['DV'], errors='coerce')

# Perform one-sample t-test
t_statistic, p_value = ttest_1samp(df[df['SECTION'] == 'BETA']['DV'].dropna(), df["DV"].mean())

print(f"T-statistic: {t_statistic}, P-value: {p_value}")
# Out:
# T-statistic: -4.510583742431786, P-value: 3.202409262188169e-05

# %%
df["Grade"]=((df["TOTAL"]/120)*10).round().astype("Int64")
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL  Grade
# 0       1   ALPHA  12     0  17     9  19    15     72     72      6
# 1       2   ALPHA  19    12  16    16  18     3     84     84      7
# 2       3   ALPHA  18    14  18    18  18    16    102    102      8
# 3       4   ALPHA  15     9  19    17  19    15     94     94      8
# 4       5   ALPHA  18    17  19    19  20    18    111    111      9
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...    ...
# 475   451       0  18     2  12     3  17    15     67     67      6
# 476   452       0  20     6  16    11  20    14     87     87      7
# 477   453       0  20     0  18    13  20    18     89     89      7
# 478   454       0  20    20   5    19  18    14     96     96      8
# 479   455       0  20    16  18    19  20    19    112    112      9
#
# [455 rows x 11 columns]

# %%
subject_columns = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
subject_columns
# Out:
# ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']

# %%
df[subject_columns] = df[subject_columns].apply(pd.to_numeric, errors='coerce')
df[subject_columns] = df[subject_columns].fillna(0)

# %%
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL  Grade
# 0       1   ALPHA  12     0  17     9  19    15     72     72      6
# 1       2   ALPHA  19    12  16    16  18     3     84     84      7
# 2       3   ALPHA  18    14  18    18  18    16    102    102      8
# 3       4   ALPHA  15     9  19    17  19    15     94     94      8
# 4       5   ALPHA  18    17  19    19  20    18    111    111      9
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...    ...
# 475   451       0  18     2  12     3  17    15     67     67      6
# 476   452       0  20     6  16    11  20    14     87     87      7
# 477   453       0  20     0  18    13  20    18     89     89      7
# 478   454       0  20    20   5    19  18    14     96     96      8
# 479   455       0  20    16  18    19  20    19    112    112      9
#
# [455 rows x 11 columns]

# %%
df['TOTAL'] = df[subject_columns].sum(axis=1)

# %%
fd=df['DV']<10
fd.value_counts()
# Out:
# DV
# False    406
# True      49
# Name: count, dtype: Int64

# %%
df.DV.value_counts()
# Out:
# DV
# 17    53
# 20    51
# 18    47
# 16    47
# 15    43
# 19    38
# 11    30
# 12    27
# 13    25
# 14    24
# 10    21
# 9     13
# 6      8
# 8      8
# 5      7
# 7      4
# 4      3
# 2      3
# 1      1
# 3      1
# 0      1
# Name: count, dtype: Int64

# %%
df["Percentage"]=df.TOTAL/60 *100
df.fillna(0,inplace=True)
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL  Grade  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72      6
# 1       2   ALPHA  19    12  16    16  18     3     84     84      7
# 2       3   ALPHA  18    14  18    18  18    16    102    102      8
# 3       4   ALPHA  15     9  19    17  19    15     94     94      8
# 4       5   ALPHA  18    17  19    19  20    18    111    111      9
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...    ...
# 475   451       0  18     2  12     3  17    15     67     67      6
# 476   452       0  20     6  16    11  20    14     87     87      7
# 477   453       0  20     0  18    13  20    18     89     89      7
# 478   454       0  20    20   5    19  18    14     96     96      8
# 479   455       0  20    16  18    19  20    19    112    112      9
#
#      Percentage
# 0         120.0
# 1         140.0
# 2         170.0
# 3    156.666667
# 4         185.0
# ..          ...
# ...

# %%
df["Grade"]=None
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL Grade  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72  None
# 1       2   ALPHA  19    12  16    16  18     3     84     84  None
# 2       3   ALPHA  18    14  18    18  18    16    102    102  None
# 3       4   ALPHA  15     9  19    17  19    15     94     94  None
# 4       5   ALPHA  18    17  19    19  20    18    111    111  None
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...   ...
# 475   451       0  18     2  12     3  17    15     67     67  None
# 476   452       0  20     6  16    11  20    14     87     87  None
# 477   453       0  20     0  18    13  20    18     89     89  None
# 478   454       0  20    20   5    19  18    14     96     96  None
# 479   455       0  20    16  18    19  20    19    112    112  None
#
#      Percentage
# 0         120.0
# 1         140.0
# 2         170.0
# 3    156.666667
# 4         185.0
# ..          ...
# 475  111.666667
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL Grade  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72  None
# 1       2   ALPHA  19    12  16    16  18     3     84     84  None
# 2       3   ALPHA  18    14  18    18  18    16    102    102  None
# 3       4   ALPHA  15     9  19    17  19    15     94     94  None
# 4       5   ALPHA  18    17  19    19  20    18    111    111  None
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...   ...
# 475   451       0  18     2  12     3  17    15     67     67  None
# 476   452       0  20     6  16    11  20    14     87     87  None
# 477   453       0  20     0  18    13  20    18     89     89  None
# 478   454       0  20    20   5    19  18    14     96     96  None
# 479   455       0  20    16  18    19  20    19    112    112  None
#
#      Percentage
# 0         120.0
# 1         140.0
# 2         170.0
# 3    156.666667
# 4         185.0
# ...

# %%
df.loc[df["TOTAL"]>110,["Grade"]]="A+"
df.loc[(df["TOTAL"]>90) & (df["TOTAL"]<=110),["Grade"]]="A"
df.loc[(df["TOTAL"]>70) & (df["TOTAL"]<=90),["Grade"]]="B+"
df.loc[(df["TOTAL"]>50) & (df["TOTAL"]<=70),["Grade"]]="B"
df.loc[(df["TOTAL"]<=50),["Grade"]]="Fail"
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL Grade  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72    B+
# 1       2   ALPHA  19    12  16    16  18     3     84     84    B+
# 2       3   ALPHA  18    14  18    18  18    16    102    102     A
# 3       4   ALPHA  15     9  19    17  19    15     94     94     A
# 4       5   ALPHA  18    17  19    19  20    18    111    111    A+
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...   ...
# 475   451       0  18     2  12     3  17    15     67     67     B
# 476   452       0  20     6  16    11  20    14     87     87    B+
# 477   453       0  20     0  18    13  20    18     89     89    B+
# 478   454       0  20    20   5    19  18    14     96     96     A
# 479   455       0  20    16  18    19  20    19    112    112    A+
#
#      Percentage
# 0         120.0
# 1         140.0
# 2         170.0
# 3    156.666667
# 4         185.0
# ..          ...
# 475  111.666667
# ...

# %%
df["backlog"]=None
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL Grade  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72    B+
# 1       2   ALPHA  19    12  16    16  18     3     84     84    B+
# 2       3   ALPHA  18    14  18    18  18    16    102    102     A
# 3       4   ALPHA  15     9  19    17  19    15     94     94     A
# 4       5   ALPHA  18    17  19    19  20    18    111    111    A+
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...   ...
# 475   451       0  18     2  12     3  17    15     67     67     B
# 476   452       0  20     6  16    11  20    14     87     87    B+
# 477   453       0  20     0  18    13  20    18     89     89    B+
# 478   454       0  20    20   5    19  18    14     96     96     A
# 479   455       0  20    16  18    19  20    19    112    112    A+
#
#      Percentage backlog
# 0         120.0    None
# 1         140.0    None
# 2         170.0    None
# 3    156.666667    None
# ...

# %%
df['Backlog_Count'] = (
    (df['DV'] < 10).astype(int) +
    (df['M-II'] < 10).astype(int) +
    (df['PP'] < 10).astype(int) +
    (df['BEEE'] < 10).astype(int) +
    (df['FL'] < 10).astype(int) +
    (df['FIMS'] < 10).astype(int)
)

df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL Grade  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72    B+
# 1       2   ALPHA  19    12  16    16  18     3     84     84    B+
# 2       3   ALPHA  18    14  18    18  18    16    102    102     A
# 3       4   ALPHA  15     9  19    17  19    15     94     94     A
# 4       5   ALPHA  18    17  19    19  20    18    111    111    A+
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...   ...
# 475   451       0  18     2  12     3  17    15     67     67     B
# 476   452       0  20     6  16    11  20    14     87     87    B+
# 477   453       0  20     0  18    13  20    18     89     89    B+
# 478   454       0  20    20   5    19  18    14     96     96     A
# 479   455       0  20    16  18    19  20    19    112    112    A+
#
#      Percentage backlog  Backlog_Count
# 0         120.0    None              2
# 1         140.0    None              1
# ...

# %%
df_sorted = df.sort_values(by="TOTAL", ascending=False)
df_sorted
# Out:
#      S.NO  SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL Grade  \
# 471   447        0  20    20  20    20  20    20    120    120    A+
# 473   449        0  20    20  20    20  20    20    120    120    A+
# 217   212  EPSILON  20    20  20    19  20    20    119    119    A+
# 419   400    SIGMA  20    20  20    20  20    19    119    119    A+
# 23     23    ALPHA  20    20  20    20  20    18    118    118    A+
# ..    ...      ...  ..   ...  ..   ...  ..   ...    ...    ...   ...
# 311   302    OMEGA   6     0   1    11   9     4     31     31  Fail
# 316   307    OMEGA  14     0   1     6   6     1     28     28  Fail
# 393   375    OMEGA   2     5   1     2  10     6     26     26  Fail
# 324   315    SIGMA   6     0   3     3  10     4     26     26  Fail
# 323   314    SIGMA   9     0   2     3  11     1     26     26  Fail
#
#      Percentage backlog  Backlog_Count
# 471       200.0    None              0
# 473       200.0    None              0
# ...

# %%
df['PP'] = pd.to_numeric(df['PP'], errors='coerce')

def assign_grade(pp):
    if pp >= 18:
        return 'Excellent'
    elif pp >= 15:
        return 'Very Good'
    elif pp >= 10:
        return 'Good'
    else:
        return 'Needs Improvement'

df['Grade'] = df['PP'].apply(assign_grade)
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72
# 1       2   ALPHA  19    12  16    16  18     3     84     84
# 2       3   ALPHA  18    14  18    18  18    16    102    102
# 3       4   ALPHA  15     9  19    17  19    15     94     94
# 4       5   ALPHA  18    17  19    19  20    18    111    111
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...
# 475   451       0  18     2  12     3  17    15     67     67
# 476   452       0  20     6  16    11  20    14     87     87
# 477   453       0  20     0  18    13  20    18     89     89
# 478   454       0  20    20   5    19  18    14     96     96
# 479   455       0  20    16  18    19  20    19    112    112
#
#                  Grade  Percentage backlog  Backlog_Count
# 0            Very Good       120.0    None              2
# 1            Very Good       140.0    None              1
# ...

# %%
def assign_grade(PP):
    if 18 <= PP <= 20:
        return 'Very Good'
    elif 15 <= PP <= 17:
        return 'Good'
    elif 13 <= PP <= 14:
        return 'Average'
    else:
        return 'Poor'

df['programming skills'] = df['PP'].apply(assign_grade)
df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72
# 1       2   ALPHA  19    12  16    16  18     3     84     84
# 2       3   ALPHA  18    14  18    18  18    16    102    102
# 3       4   ALPHA  15     9  19    17  19    15     94     94
# 4       5   ALPHA  18    17  19    19  20    18    111    111
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...
# 475   451       0  18     2  12     3  17    15     67     67
# 476   452       0  20     6  16    11  20    14     87     87
# 477   453       0  20     0  18    13  20    18     89     89
# 478   454       0  20    20   5    19  18    14     96     96
# 479   455       0  20    16  18    19  20    19    112    112
#
#                  Grade  Percentage backlog  Backlog_Count programming skills
# 0            Very Good       120.0    None              2               Good
# ...

# %%
df["status"] = (
    (df['DV'] ==20).astype(int) +
    (df['M-II'] ==20).astype(int) +
    (df['PP'] ==20).astype(int) +
    (df['BEEE'] ==20).astype(int) +
    (df['FL'] ==20).astype(int) +
    (df['FIMS'] ==20).astype(int)
)

df
# Out:
#      S.NO SECTION  DV  M-II  PP  BEEE  FL  FIMS  Total  TOTAL  \
# 0       1   ALPHA  12     0  17     9  19    15     72     72
# 1       2   ALPHA  19    12  16    16  18     3     84     84
# 2       3   ALPHA  18    14  18    18  18    16    102    102
# 3       4   ALPHA  15     9  19    17  19    15     94     94
# 4       5   ALPHA  18    17  19    19  20    18    111    111
# ..    ...     ...  ..   ...  ..   ...  ..   ...    ...    ...
# 475   451       0  18     2  12     3  17    15     67     67
# 476   452       0  20     6  16    11  20    14     87     87
# 477   453       0  20     0  18    13  20    18     89     89
# 478   454       0  20    20   5    19  18    14     96     96
# 479   455       0  20    16  18    19  20    19    112    112
#
#                  Grade  Percentage backlog  Backlog_Count programming skills  \
# 0            Very Good       120.0    None              2               Good
# ...

# %%
subject_columns = df.columns[2:]
max_scores = {}

for subject in subject_columns:
    if pd.api.types.is_numeric_dtype(df[subject]):
        max_score = df[subject].max()
        count = (df[subject] == max_score).sum()
        max_scores[subject] = {'Max Score': max_score, 'Count': count}

print(max_scores)
# Out:
# {'DV': {'Max Score': 20, 'Count': 51}, 'M-II': {'Max Score': 20, 'Count': 44}, 'PP': {'Max Score': 20, 'Count': 70}, 'BEEE': {'Max Score': 20, 'Count': 74}, 'FL': {'Max Score': 20, 'Count': 119}, 'FIMS': {'Max Score': 20, 'Count': 12}, 'Total': {'Max Score': 120, 'Count': 2}, 'TOTAL': {'Max Score': 120, 'Count': 2}, 'Percentage': {'Max Score': 200.0, 'Count': 2}, 'Backlog_Count': {'Max Score': 5, 'Count': 9}, 'status': {'Max Score': 6, 'Count': 2}}

# %%
plt.figure(figsize=[8, 6])
plt.hist(df['Grade'], color='blue', bins=10, edgecolor='black')
plt.title("Distribution of Grade")
plt.xlabel("Grade")
plt.ylabel("Number of Students")
plt.show()

# %%
plt.figure(figsize=[8, 6])
plt.hist(df['TOTAL'], color='blue', bins=10, edgecolor='black')
plt.title("Distribution of Total Marks")
plt.xlabel("Total Marks")
plt.ylabel("Number of Students")
plt.show()

# %% [markdown]
# # The histogram will show the distribution of students' total marks

# %%
average_total_by_section = df.groupby('SECTION')['TOTAL'].mean()
print("Average Total Marks by Section:")
print(average_total_by_section)
# Out:
# Average Total Marks by Section:
# SECTION
# 0          90.027027
# ALPHA      88.966102
# BETA       84.305085
# DELTA      83.789474
# EPSILON    79.614035
# GAMMA      76.627119
# OMEGA      78.929825
# SIGMA      78.403509
# ZETA            82.0
# Name: TOTAL, dtype: Float64

# %% [markdown]
# # average total marks for each section

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='bar', color='blue')
plt.title("Average Total Marks by Section")
plt.xlabel("Section")
plt.ylabel("Average Total Marks")
plt.xticks(rotation=90)
plt.show()

# %%
subject_columns = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
subject_averages = df[subject_columns].mean()

# %%
plt.figure(figsize=[8, 6])
subject_averages.plot(kind='bar', color='red')
plt.title("Subject-wise Average Scores")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['M-II'], bins=10,color='orange')
plt.title('Distribution of Marks in M-II', fontsize=16)
plt.xlabel('Marks in M-II', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['DV'], bins=10,color='blue')
plt.title('Distribution of Marks in DV', fontsize=16)
plt.xlabel('Marks in DV', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# # Shows the distribution of marks in the subject 'DV'. Peaks in the histogram indicate the marks ranges most students achieved.

# %%
plt.figure(figsize=[8, 6])
plt.hist(df['TOTAL'], color='blue', bins=10, edgecolor='black')
plt.title("Distribution of Total Marks")
plt.xlabel("Total Marks")
plt.ylabel("Number of Students")
# Out:
# Text(0, 0.5, 'Number of Students')

# %% [markdown]
# # Distribution of total marks

# %%
subject_columns = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
subject_averages = df[subject_columns].mean()
subject_averages
# Out:
# DV       14.78022
# M-II    10.459341
# PP      13.375824
# BEEE    13.659341
# FL      15.881319
# FIMS    14.092308
# dtype: Float64

# %%
plt.figure(figsize=(10, 6))
subject_averages.plot(kind='bar', color='skyblue')
plt.title('Average Marks per Subject', fontsize=16)
plt.xlabel('Subjects', fontsize=12)
plt.ylabel('Average Marks', fontsize=12)
plt.xticks(rotation=90)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Average marks each subject

# %%
subject_with_highest_avg = df[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].mean().idxmax()
plt.figure(figsize=(8, 5))
sns.histplot(df[subject_with_highest_avg], bins=10, color='orange')
plt.title(f'Distribution of Marks in {subject_with_highest_avg}', fontsize=16)
plt.xlabel(f'Marks in {subject_with_highest_avg}', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# # Distribution of marks in fl subject

# %%
average_total_by_section = df.groupby('SECTION')['TOTAL'].mean()
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='bar', color='purple', edgecolor='black')
plt.title("Average Total Marks by Section")
plt.xlabel("Section")
plt.ylabel("Average Total Marks")
plt.show()

# %% [markdown]
# # Adding Percentage Column

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Percentage'], bins=10, color='teal')
plt.title('Distribution of Percentages', fontsize=16)
plt.xlabel('Percentage', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# # This visualization shows distribution of percentages

# %%
plt.figure(figsize=[8, 6])
subject_averages.plot(kind='pie', autopct='%1.1f%%', colors=['green', 'orange', 'blue', 'red', 'purple', 'yellow'])
plt.title("Subject-wise Average Scores")
plt.show()

# %% [markdown]
# # This pie chart represents the Subject-wise Average Scores in subject

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("Subject-wise Average Scores")
plt.ylabel('')
plt.show()

# %% [markdown]
# # This pie chart represents the Subject-wise Average Scores in section wise

# %%
plt.figure(figsize=[8, 6])
average_total_by_section.plot(kind='pie', autopct='%1.1f%%', colors=['cyan', 'magenta', 'lime', 'gold', 'violet', 'darkorange'])
plt.title("Subject-wise Average Scores")
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='DV', y='M-II', color='red')
plt.title('Scatter Plot of Marks: DV vs M-II', fontsize=16)
plt.xlabel('Marks in DV', fontsize=12)
plt.ylabel('Marks in M-II', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# # This scatter plot examines how total marks relate to the percentage scores.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='PP', y='BEEE', color='green', s=100)
plt.title('Relationship Between Marks in PP and BEEE', fontsize=16)
plt.xlabel('Marks in PP', fontsize=12)
plt.ylabel('Marks in BEEE', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# # This scatter plot shows how marks in BEEE relate to marks in for each student.

# %%
plt.figure(figsize=[8, 6])
plt.scatter(df['TOTAL'], df['BEEE'], color='orange', edgecolor='black')
plt.title("Scatter Plot: Total Marks vs BEEE Marks")
plt.xlabel("Total Marks")
plt.ylabel("BEEE Marks")
plt.show()

# %% [markdown]
# # This scatter plot helps you see how individual subject marks (DV) correlate with overall TOTAL marks.

# %% [markdown]
# # seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.relplot(data=df, x="Percentage", y="Backlog_Count")

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Backlog_Count', data=df)
plt.title('Distribution Backlog Counts', fontsize=18)
plt.xlabel('Backlog Count', fontsize=14)
plt.ylabel('Number of Students', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
subject_backlogs = (df[subject_columns] < 10).sum().sort_values(ascending=False)
print("\nSubject-Wise Backlog Counts:")
print(subject_backlogs)
# Out:
# Subject-Wise Backlog Counts:
# M-II    205
# PP      115
# BEEE    108
# FIMS     69
# DV       49
# FL       14
# dtype: Int32

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=subject_backlogs.index, y=subject_backlogs.values)
plt.title('Backlog Count by Subject', fontsize=16)
plt.xlabel('Subjects', fontsize=14)
plt.ylabel('Number of Students with Backlogs', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Backlog Count by Subject

# %%
if 'SECTION' in df.columns:
    section_backlog_counts = df.groupby('SECTION')['Backlog_Count'].mean().sort_values()
    print("\nAverage Backlog Count by Section:")
    print(section_backlog_counts)
# Out:
# Average Backlog Count by Section:
# SECTION
# ALPHA      0.711864
# BETA       1.067797
# 0          1.081081
# DELTA      1.122807
# EPSILON    1.263158
# ZETA       1.307692
# OMEGA      1.491228
# SIGMA      1.491228
# GAMMA      1.559322
# Name: Backlog_Count, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=section_backlog_counts.index, y=section_backlog_counts.values)
plt.title('Average Backlog Count by Section', fontsize=18)
plt.xlabel('Section', fontsize=14)
plt.ylabel('Average Backlog Count', fontsize=8)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Backlog Percentage by Subject

# %%
top_backlog_students = df.sort_values(by='Backlog_Count', ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_backlog_students['S.NO'], y=top_backlog_students['Backlog_Count'])
plt.title('Top 10 Students with  Most Backlogs', fontsize=16)
plt.xlabel('Student Number (S.NO)', fontsize=6)
plt.ylabel('Backlog Count', fontsize=6)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # Average Backlog Count by Section

# %%
subject_backlog_percentage = (df[subject_columns] < 10).mean() * 100
plt.figure(figsize=(10, 6))
sns.barplot(x=subject_backlog_percentage.index, y=subject_backlog_percentage.values)
plt.title('Backlog Percentage by Subject', fontsize=8)
plt.xlabel('Subjects', fontsize=9)
plt.ylabel('Backlog Percentage (%)', fontsize=8)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
df.isnull().sum()
# Out:
# S.NO                    0
# SECTION                 0
# DV                      0
# M-II                    0
# PP                      0
# BEEE                    0
# FL                      0
# FIMS                    0
# Total                   0
# TOTAL                   0
# Grade                   0
# Percentage              0
# backlog               455
# Backlog_Count           0
# programming skills      0
# status                  0
# dtype: int64
